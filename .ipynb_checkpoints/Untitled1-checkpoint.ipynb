# %%
from service import sncf_routes

# %%
df = sncf_routes.get_routes(1,2,3)
# Out:
# Results FOUND : 3

# %%
df.head()
# Out:
#      TGV         arrivalDate availablePhysicalSpaces baseClasses bookingType  \
# 0  False 2017-08-21 14:03:00                     [B]        None          RI
# 1  False 2017-08-21 16:43:00                     [B]        None          RI
# 0  False 2017-08-21 17:44:00                     [B]        None          RI
# 0  False 2017-08-21 19:00:00                     [B]        None          RI
#
#   boundaryPoint carrierCode       departureDate         destination  \
# 0          None          SN 2017-08-21 12:55:00         FIGEAC GARE
# 1          None          SN 2017-08-21 15:30:00  BRIVE LA GAILLARDE
# 0          None          SN 2017-08-21 15:55:00  BRIVE LA GAILLARDE
# 0          None          SN 2017-08-21 17:12:00  BRIVE LA GAILLARDE
#
#   destinationCode     ...     trainEquipment  trainNumber trainPeriod  \
# 0           FRFIG     ...               None        71209        BLUE
# 1           FRBVE     ...               None        70258        BLUE
# ...
