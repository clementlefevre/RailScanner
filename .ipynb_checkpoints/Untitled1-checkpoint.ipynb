# %%
from service import sncf_routes

# %%
df = sncf_routes.get_routes("Aurillac","Clermont-Ferrand")
# Out:
# 2017-08-07T20:03:52.305737
# Aurillac
# Clermont-Ferrand
# ...

# %%
df.head()
# Out:
#      TGV         arrivalDate availablePhysicalSpaces baseClasses bookingType  \
# 0  False 2017-08-21 12:48:00                     [B]        None          RI
# 0  False 2017-08-21 14:24:00                     [B]        None          RI
# 1  False 2017-08-21 16:02:00                     [B]        None          RI
# 0  False 2017-08-21 19:05:00                     [B]        None          RI
# 0  False 2017-08-21 20:08:00                     [B]        None          RI
#
#   boundaryPoint carrierCode       departureDate            destination  \
# 0          None          SN 2017-08-21 10:22:00       CLERMONT FERRAND
# 0          None          SN 2017-08-21 13:30:00            NEUSSARGUES
# 1          None          SN 2017-08-21 14:37:00  CLERMONT FERRAND GARE
# 0          None          SN 2017-08-21 16:39:00       CLERMONT FERRAND
# 0          None          SN 2017-08-21 17:41:00       CLERMONT FERRAND
#
#   destinationCode     ...     trainEquipment  trainNumber trainPeriod  \
# ...
